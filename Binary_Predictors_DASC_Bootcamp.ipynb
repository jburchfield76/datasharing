# %% [markdown]
# <a href="https://colab.research.google.com/github/jburchfield76/datasharing/blob/master/Binary_Predictors_DASC_Bootcamp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

#Apply a fix to the statsmodels library
from scipy import stats
stats.chisqprob = lambda chisq, df: stats.chi2.sf(chisq, df)

# %%
raw_data = pd.read_csv('2.02.+Binary+predictors.csv')
raw_data
# Out:
#       SAT Admitted  Gender
# 0    1363       No    Male
# 1    1792      Yes  Female
# 2    1954      Yes  Female
# 3    1653       No    Male
# 4    1593       No    Male
# ..    ...      ...     ...
# 163  1722      Yes  Female
# 164  1750      Yes    Male
# 165  1555       No    Male
# 166  1524       No    Male
# 167  1461       No    Male
#
# [168 rows x 3 columns]

# %%
data = raw_data.copy()
data['Admitted'] = data['Admitted'].map({'Yes': 1, 'No': 0})
data['Gender'] = data['Gender'].map({'Female': 1, 'Male': 0})
data
# Out:
#       SAT  Admitted  Gender
# 0    1363         0       0
# 1    1792         1       1
# 2    1954         1       1
# 3    1653         0       0
# 4    1593         0       0
# ..    ...       ...     ...
# 163  1722         1       1
# 164  1750         1       0
# 165  1555         0       0
# 166  1524         0       0
# 167  1461         0       0
#
# [168 rows x 3 columns]

# %%
y = data['Admitted']
x1 = data[['SAT','Gender']]

# %%
x = sm.add_constant(x1)
reg_log = sm.Logit(y,x)
results_log = reg_log.fit()
results_log.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.120117
#          Iterations 10
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:               Admitted   No. Observations:                  168
# Model:                          Logit   Df Residuals:                      165
# Method:                           MLE   Df Model:                            2
# Date:                Wed, 18 Jun 2025   Pseudo R-squ.:                  0.8249
# Time:                        21:40:11   Log-Likelihood:                -20.180
# converged:                       True   LL-Null:                       -115.26
# Covariance Type:            nonrobust   LLR p-value:                 5.118e-42
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
np.exp(1.9449)
# Out:
# np.float64(6.992932526814459)
